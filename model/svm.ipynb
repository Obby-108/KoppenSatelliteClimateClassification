# %%
import sklearn as sk

#  X = dataloader(koppen_dataset).input
    # normalize and standardize
#  y = dataloader(koppen_dataset).labels
svm = sk.svm.SVC()
# svm.fit(X, y)
    # validation included
# testing accuracy at end
