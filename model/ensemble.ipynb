# %%
import numpy as np
import h5py
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report

# %%
SEED = 42
# Import data via h5py compressed file
with h5py.File('svm_ready_data.h5', 'r') as hf:
    # Extract into standard numpy arrays
    X_train = np.array(hf['X_train'])
    y_train = np.array(hf['y_train'])
    X_test = np.array(hf['X_test'])
    y_test = np.array(hf['y_test'])
print("Successfully retrieved 5-statistic/12-class/60-feature data.")

# Standardize the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
# Out:
# Successfully retrieved 5-statistic/12-class/60-feature data.

# %%
# Define RF model
rf_model = RandomForestClassifier(
    n_estimators=500,
    max_depth=20,
    n_jobs=-1,  # Use all CPU cores
    random_state=SEED,
    class_weight='balanced'
)

# Fit model to training data
rf_model.fit(X_train, y_train)

# Evaluate on test data
outputs = rf_model.predict(X_test)
print(classification_report(y_test, outputs))
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 160 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 410 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed:   10.1s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 160 tasks      | elapsed:    0.0s
#               precision    recall  f1-score   support
#
#            1       0.62      0.67      0.64       317
#            2       0.50      0.48      0.49       362
#            3       0.43      0.41      0.42       408
#            4       0.76      0.63      0.69       429
#            5       0.49      0.63      0.55       361
#            6       0.45      0.45      0.45       438
#            7       0.36      0.31      0.33       399
#            8       0.44      0.37      0.40       367
#            9       0.40      0.22      0.28       388
#           10       0.53      0.63      0.58       376
#           11       0.39      0.40      0.39       385
#           12       0.32      0.37      0.34       385
#           13       0.71      0.87      0.78       435
#           14       0.41      0.47      0.43       398
#           15       0.38      0.35      0.37       396
#           16       0.55      0.69      0.61       394
#           17       0.51      0.70      0.59       408
#           18       0.37      0.25      0.30       399
#           19       0.45      0.30      0.36       402
#           20       0.50      0.73      0.59       343
#           21       0.46      0.57      0.51       409
#           22       0.46      0.43      0.45       401
#           23       0.42      0.26      0.32       438
#           24       0.57      0.60      0.58       409
#           25       0.39      0.40      0.40       391
#           26       0.38      0.30      0.34       432
#           27       0.48      0.42      0.45       373
#           28       0.46      0.49      0.48       410
#           29       0.51      0.53      0.52       400
#           30       0.88      0.89      0.89       407
#
#     accuracy                           0.49     11860
#    macro avg       0.49      0.49      0.48     11860
# weighted avg       0.49      0.49      0.48     11860
# [Parallel(n_jobs=20)]: Done 410 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=20)]: Done 500 out of 500 | elapsed:    0.2s finished

# %%
# Define GBC model
gbc_model = GradientBoostingClassifier(
    n_estimators=100,
    learning_rate=0.1,
    max_depth=5,
    subsample=0.8,
    validation_fraction=0.1,
    n_iter_no_change=5,
    verbose=1,
    random_state=SEED
)

# Fit model on training data
gbc_model.fit(X_train, y_train)

# Evaluate on test data
outputs = gbc_model.predict(X_test)
print(classification_report(y_test, outputs))
# Out:
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1           2.8650           0.4712           26.03m
#          2           2.6626           0.2259           25.98m
#          3           2.5128           0.1523           25.84m
#          4           2.3894           0.1264           25.48m
#          5           2.2908           0.1100           25.20m
#          6           2.2015           0.0774           25.01m
#          7           2.1268           0.0761           25.05m
#          8           2.0652           0.0879           24.97m
#          9           2.0000           0.0370           24.76m
#         10           1.9456           0.0462           24.65m
#         20           1.6120           0.0244           22.70m
#         30           1.4235           0.0152           19.60m
#         40           1.2925           0.0301           16.61m
#         50           1.1771          -0.0181           13.77m
#               precision    recall  f1-score   support
#
#            1       0.61      0.58      0.59       317
#            2       0.46      0.46      0.46       362
#            3       0.39      0.37      0.38       408
#            4       0.75      0.60      0.66       429
#            5       0.46      0.56      0.50       361
#            6       0.42      0.45      0.44       438
#            7       0.32      0.33      0.32       399
#            8       0.35      0.34      0.35       367
#            9       0.32      0.24      0.27       388
#           10       0.50      0.56      0.53       376
#           11       0.31      0.31      0.31       385
#           12       0.30      0.34      0.32       385
#           13       0.74      0.81      0.77       435
#           14       0.39      0.41      0.40       398
#           15       0.39      0.33      0.36       396
#           16       0.56      0.55      0.56       394
#           17       0.47      0.63      0.54       408
#           18       0.26      0.21      0.23       399
#           19       0.36      0.23      0.28       402
#           20       0.47      0.64      0.54       343
#           21       0.44      0.50      0.47       409
#           22       0.42      0.41      0.42       401
#           23       0.33      0.22      0.26       438
#           24       0.57      0.57      0.57       409
#           25       0.38      0.40      0.39       391
#           26       0.33      0.30      0.31       432
#           27       0.44      0.43      0.44       373
#           28       0.43      0.48      0.46       410
#           29       0.47      0.52      0.49       400
#           30       0.86      0.87      0.87       407
#
#     accuracy                           0.45     11860
#    macro avg       0.45      0.45      0.45     11860
# weighted avg       0.45      0.45      0.45     11860
